# %% [markdown]
# # Pitt County Eviction Early Warning (Pilot)
#
# This notebook demonstrates a baseline eviction early-warning score using rolling z-scores.

# %%
import pandas as pd
import numpy as np

print('Notebook loaded successfully')
